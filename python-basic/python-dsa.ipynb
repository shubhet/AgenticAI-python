# %%
#string

s='Hello Java'
print(s)
# Out:
# Hello Java

# %%
#list
#ist is an ordered, mutable collection.
#duplicate allowed

list_data = ["Ravi","24","Java","Java"]
print(list_data)
print(list_data[0])
# Out:
# ['Ravi', '24', 'Java', 'Java']
# Ravi

# %%
#tupple
#tuple is an ordered, immutable collection.
#duplicate allowed

tupple_data =("Ravi","24","Java","Java")
print(tupple_data)
print(tupple_data[0])
print(tupple_data[1])
# Out:
# ('Ravi', '24', 'Java', 'Java', 'java')
# Ravi
# 24

# %%
#set
#set stores unique elements.
#duplicate not allowed
#unordered

set_data = {"Ravi","24","Java","Java","java"}
print(set_data)

#print(set_data[0])--# we can't do it's unordered

#need to convert into list then can access the data
list_data = list(set_data)
print(list_data)
print(list_data[0])
# Out:
# {'Ravi', '24', 'java', 'Java'}
# ['Ravi', '24', 'java', 'Java']
# Ravi

# %%
#dictionary
#dictionary stores key-value pairs.

dict_data = {"name":"Ravi","age":"24","language":"Java"}
print(dict_data)
print(dict_data["name"])
# Out:
# {'name': 'Ravi', 'age': '24', 'language': 'Java'}
# Ravi

# %%
import numpy as np

arr = np.array([10,20,30])
print(arr)
print(arr[0])
# Out:
# [10 20 30]
# 10

# %%
# !pip install numpy
# Out:
# ...
#   Using cached numpy-2.5.0-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.5.0-cp312-cp312-win_amd64.whl (12.4 MB)
# ...
